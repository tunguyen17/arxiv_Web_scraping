# %%
from bs4 import BeautifulSoup
import urllib
import urllib.request
import io
import re

# %%
# # The URL
# url = "https://arxiv.org/find/stat/1/au:+Young_S/0/1/0/all/0/1"

# # Fetch the url's HTML code
# u = urllib.request.urlopen(url, data = None)
# f = io.TextIOWrapper(u,encoding='utf-8')
# text = f.read()

# # Using beautiful soup to read 
# soup = BeautifulSoup(text, 'html.parser')

# # Using beautiful soup to find the content within the class "primary-subject"
# lst = soup.find_all(attrs={'class': "primary-subject"})

# # Get the shortted version of the primary subject
# for i in lst:
#     temp = re.search("\(([^)]+)\.", str(i))[0]
#     print(temp[1:-1])

# %% [markdown]
# # Note on arXiv API
#
# https://arxiv.org/help/api/user-manual#_query_interface
#
# http://export.arxiv.org/api/{method_name}?{parameters}
#
# method_name = query
#
# | Parameter    | Type                    |
# |--------------|-------------------------|
# | search_query | string                  |
# | id_list      |  comma-delimited string |
# | start        |  int                    |
# | max_results  | int                     |
#
# The parameter are connected using '&'
#
#
# http://export.arxiv.org/api/query?search_query=au:{author}
#
#
# | Prefix | Explanation       |
# |--------|-------------------|
# | ti     | Title             |
# | au     | Author            |
# | abs    | Abstract          |
# | co     | Comment           |
# | jr     | Journal Reference |
# | cat    | Subject Category  |
# | rn     | Report Number     |
# | all    | All of the above  |

# %%
# Out:
# 'Adrian+Del+Maestro'

# %%
query_au('Aleksandar Milosavljevic')
# Out:
# ['q-bio',
#  'cs',
#  'cs',
#  'hep-lat',
#  'hep-th',
#  'math',
#  'math',
#  'math',
#  'math',
#  'math']

# %%
# The URL
# url = "http://export.arxiv.org/api/query?search_query=au:del_maestro"
url = "http://export.arxiv.org/api/query?search_query=cat:q-bio"
# url = "http://export.arxiv.org/api/query?search_query=all:electron&start=0&max_results=1000"

# Fetch the url's HTML code
u = urllib.request.urlopen(url, data = None)
f = io.TextIOWrapper(u,encoding='utf-8')
text = f.read()

# Using beautiful soup to read 
soup = BeautifulSoup(text, 'xml')

# %%
for i in soup.findAll("entry"):
    # iterate through each paper
   
    # Author part
    au = [] # Initialize the list of authors
    for j in i.findAll("author"):
        au.append(j.find("name").contents[0]) # Append to the list of authors
    
    # Paper part
    # Get the primary category of each paper
    try:
        prim_cat = re.search("^(.+)\.", i.primary_category["term"]).group(1)
#         print( i.primary_category["term"])
    except:
        prim_cat = i.primary_category["term"]
    print(au)
    print(prim_cat)
    print("\n ----- \n")
# Out:
# ['Ulrich H. E. Hansmann', 'Yuko Okamoto']
# cond-mat
#
#  -----
#
# ['H. Rosu', 'E. Canessa']
# cond-mat
#
#  -----
#
# ['Marc Potters', 'William Bialek']
# cond-mat
#
#  -----
#
# ['Nicolas Brunel', 'Riccardo Zecchina']
# cond-mat
#
#  -----
#
# ['S. Flach', 'C. R. Willis']
# cond-mat
#
#  -----
#
# ['Michal Kurzynski']
# cond-mat
#
#  -----
#
# ['Jan de Boer', 'A. D. Jackson', 'Tilo Wettig']
# cond-mat
#
#  -----
#
# ['H. F. Chau', 'L. Mak', 'P. K. Kwok']
# cond-mat
#
#  -----
#
# ['Thadeu J. P. Penna']
# cond-mat
#
#  -----
#
# ['T. J. P. Penna', 'D. Stauffer']
# cond-mat
#
#  -----

# %%
# Getting all the categories

# The URL
url = "https://arxiv.org/help/api/user-manual#subject_classifications"

# Fetch the url's HTML code
u = urllib.request.urlopen(url, data = None)
f = io.TextIOWrapper(u,encoding='utf-8')
text = f.read()

# Using beautiful soup to read 
soup = BeautifulSoup(text, 'html.parser')

# Using beautiful soup to find all the table
table_lst = soup.findAll('table')

cat_lst_gen = [] # General category list
cat_lst_spe = [] # Specific category list
cat_dict = {}
for (index, specific) in enumerate(table_lst[-1].findAll("td")):
    if(index%2 or index ==0):
        pass
    else:
#         print(index)
        # only get the abbreviation
        specific = specific.contents[0].strip()
        
        try:
            general = re.search("^(.+)\.", specific).group(1)
        except:
            general = specific
        
        if general in cat_dict.keys():
            if specific not in cat_dict[general]:
                cat_dict[general].append(specific)
        else:
            cat_dict.update({general: [specific]})

# %%
cat_dict
# Out:
# {'astro-ph': ['astro-ph'],
#  'cond-mat': ['cond-mat.dis-nn',
#   'cond-mat.mes-hall',
#   'cond-mat.mtrl-sci',
#   'cond-mat.other',
#   'cond-mat.soft',
#   'cond-mat.stat-mech',
#   'cond-mat.str-el',
#   'cond-mat.supr-con'],
#  'cs': ['cs.AR',
#   'cs.AI',
#   'cs.CL',
#   'cs.CC',
#   'cs.CE',
#   'cs.CG',
#   'cs.GT',
#   'cs.CV',
#   'cs.CY',
#   'cs.CR',
#   'cs.DS',
#   'cs.DB',
#   'cs.DL',
#   'cs.DM',
#   'cs.DC',
#   'cs.GL',
#   'cs.GR',
#   'cs.HC',
#   'cs.IR',
#   'cs.IT',
#   'cs.LG',
#   'cs.LO',
#   'cs.MS',
#   'cs.MA',
#   'cs.MM',
#   'cs.NI',
#   'cs.NE',
#   'cs.NA',
#   'cs.OS',
#   'cs.OH',
#   'cs.PF',
#   'cs.PL',
#   'cs.RO',
#   'cs.SE',
#   'cs.SD',
#   'cs.SC'],
#  'gr-qc': ['gr-qc'],
#  'hep-ex': ['hep-ex'],
#  'hep-lat': ['hep-lat'],
#  'hep-ph': ['hep-ph'],
#  'hep-th': ['hep-th'],
#  'math': ['math.AG',
#   'math.AT',
#   'math.AP',
#   'math.CT',
#   'math.CA',
#   'math.CO',
#   'math.AC',
#   'math.CV',
#   'math.DG',
#   'math.DS',
#   'math.FA',
#   'math.GM',
#   'math.GN',
#   'math.GT',
#   'math.GR',
#   'math.HO',
#   'math.IT',
#   'math.KT',
#   'math.LO',
#   'math.MP',
#   'math.MG',
#   'math.NT',
#   'math.NA',
#   'math.OA',
#   'math.OC',
#   'math.PR',
#   'math.QA',
#   'math.RT',
#   'math.RA',
#   'math.SP',
#   'math.ST',
#   'math.SG'],
#  'math-ph': ['math-ph'],
#  'nlin': ['nlin.AO', 'nlin.CG', 'nlin.CD', 'nlin.SI', 'nlin.PS'],
#  'nucl-ex': ['nucl-ex'],
#  'nucl-th': ['nucl-th'],
#  'physics': ['physics.acc-ph',
#   'physics.ao-ph',
#   'physics.atom-ph',
#   'physics.atm-clus',
#   'physics.bio-ph',
#   'physics.chem-ph',
#   'physics.class-ph',
#   'physics.comp-ph',
#   'physics.data-an',
#   'physics.flu-dyn',
#   'physics.gen-ph',
#   'physics.geo-ph',
#   'physics.hist-ph',
#   'physics.ins-det',
#   'physics.med-ph',
#   'physics.optics',
#   'physics.ed-ph',
#   'physics.soc-ph',
#   'physics.plasm-ph',
#   'physics.pop-ph',
#   'physics.space-ph'],
#  'q-bio': ['q-bio.BM',
#   'q-bio.CB',
#   'q-bio.GN',
#   'q-bio.MN',
#   'q-bio.NC',
#   'q-bio.OT',
#   'q-bio.PE',
#   'q-bio.QM',
#   'q-bio.SC',
#   'q-bio.TO'],
#  'quant-ph': ['quant-ph'],
#  'stat': ['stat.AP', 'stat.CO', 'stat.ML', 'stat.ME', 'stat.TH']}

# %%
def query_cat(cat):
    '''
    Query to find authors from a category
    '''
    url = "http://export.arxiv.org/api/query?search_query=cat:"+cat
    u = urllib.request.urlopen(url, data = None)
    f = io.TextIOWrapper(u,encoding='utf-8')
    text = f.read()

    # Using beautiful soup to read 
    soup = BeautifulSoup(text, 'xml')
    
    authors = [] # Initialize the list of authors
        
    for i in soup.findAll("author"):
        if not i in authors:
            authors.append(i.find("name").contents[0]) # Append to the list of authors       
    return authors

def query_au(author):
    '''
    Query to find the author's paper category
    '''
    
    url = "http://export.arxiv.org/api/query?search_query=au:"+author.replace(" ", "+")

    # Fetch the url's HTML code
    u = urllib.request.urlopen(url, data = None)
    f = io.TextIOWrapper(u,encoding='utf-8')
    text = f.read()

    # Using beautiful soup to read 
    soup = BeautifulSoup(text, 'xml')

    cat_lst = []

    for i in soup.findAll("entry"):
        # iterate through each paper

    #     # Author part
    #     au = [] # Initialize the list of authors
    #     for j in i.findAll("author"):
    #         au.append(j.find("name").contents[0]) # Append to the list of authors

        # Paper part
        # Get the primary category of each paper
        try:
            prim_cat = re.search("^(.+)\.", i.primary_category["term"]).group(1)
    #         print( i.primary_category["term"])
        except:
            prim_cat = i.primary_category["term"]

        cat_lst.append(prim_cat)

    return cat_lst

# %%
temp = cat_dict.values()
temp = [item for subcategory in temp for item in subcategory]

# %%
au = []
for i in temp[:10]:
    au.append(query_cat(i))
    
au_lst = [author for sublist in au for author in sublist]

# %%
len(set(au_lst))
# Out:
# 252

# %%
set(au_lst)
# Out:
# {'A. Czirok',
#  'A. J. van Es',
#  'A. Manwani',
#  'A. Marciniuk',
#  'A. Volkovskii',
#  'A. Weron',
#  'Alain Trouvé',
#  'Aleksandar Milosavljevic',
#  'Alessandra Iacobucci',
#  'Alex D Gottlieb',
#  'Anastasia Papavasiliou',
#  'Andras Lorincz',
#  'Anna Lombardi',
#  'Anna Ochab-Marcinek',
#  'Arnaud Guillin',
#  'Arthur Cohen',
#  'Ayse Erzan',
#  'B. Pesaran',
#  'B. Szabo',
#  'Barnabas Poczos',
#  'Barry J. Richmond',
#  'Bert van Es',
#  'Bharath K. Sriperumbudur',
#  'Bingshan Li',
#  'Brian Herman',
#  'C. C. Chow',
#  'C. Koch',
#  'C. Soto-Trevino',
#  'Carson C. Chow',
#  'Carter Adams',
#  'Chaitanya Athale',
#  'Chaya Levovitz',
#  'Cheolwoo Park',
#  'Chien-Hung Huang',
#  'Chien-Yu Chen',
#  'Chih-Peng Wu',
#  'Chris Wiggins',
#  'Christian Olivier',
#  'Christian P. Robert',
#  'Christian Robert',
#  'Christof M. Aegerter',
#  'Christopher K. Carter',
#  'Colin Mallows',
#  'Cun-Hui Zhang',
#  'D. Biron',
#  'D. K. Klimov',
#  'D. Mirelman',
#  'D. Sagi',
#  'D. Selmeczi',
#  'D. Thirumalai',
#  'D. Volchenkov',
#  'Daniel F. McCaffrey',
#  'Daniela Russo',
#  'Darby Tien-Hao Chang',
#  "Davide Cora'",
#  'Davide La Torre',
#  'Deborah Wallace',
#  'Didier A. Depireux',
#  'Didier Concordet',
#  'Dietrich Stauffer',
#  'Djalil Chafai',
#  'Duygu Balcan',
#  'E. D. Sontag',
#  'E. J. Aguilar',
#  'E. Moses',
#  'Eli Eisenberg',
#  'Erez Y. Levanon',
#  'Eshel Ben-Jacob',
#  'Estelle Kuhn',
#  'Etay Ziv',
#  'Ethan D. Gershon',
#  'Eva Biener',
#  'Ferdinando Di Cunto',
#  'Florentin Smarandache',
#  'Fulufhelo V. Nelwamondo',
#  'G. A. Enciso',
#  'G. Csucs',
#  'G. Laurent',
#  'Galit Shmueli',
#  'Gavin E. Crooks',
#  'Gert R. G. Lanckriet',
#  'Graciela Boente',
#  'Greg Hura',
#  'Gregory Woods',
#  'Guanghong Wei',
#  'Guilhem Coq',
#  'Guodong Song',
#  'H. -W. Uh',
#  'Hans G. Othmer',
#  'Hao-Geng Hung',
#  'Harry van Zanten',
#  'Helen Armstrong',
#  'Henry D. I. Abarbanel',
#  'Herbert Levine',
#  'Housila P. Singh',
#  'Hélène Jacqmin-Gadda',
#  'Inbal Yahav',
#  'J. A. White',
#  'J. R. Lockwood',
#  'J. Ritt',
#  'J. S. Marron',
#  'J. S. Pezaris',
#  'J. Zach',
#  'Jack Allen',
#  'James V Zidek',
#  'Jan P. Radomski',
#  'Jason Ritt',
#  'Jean-Marie Cornuet',
#  'Jean-Michel Marin',
#  'Jean-Philippe Vert',
#  'Jen Hom',
#  'Jian-Hua Zhang',
#  'Jiangang Fang',
#  'Jianhui Zhou',
#  'Jie Liang',
#  'Jodie A. Smith',
#  'John A. White',
#  'John Quigley',
#  'Jonathan Weare',
#  'Jonathan Z. Simon',
#  'Joseph Naus',
#  'Joseph Rynkiewicz',
#  'K. Burnecki',
#  'Ka-Lok Ng',
#  'Kevin F. Wong',
#  'L. A. V. de Carvalho',
#  'L. E. Flores',
#  'Lesley Walls',
#  'Linda Chen',
#  'Lior Pachter',
#  'Long Wang',
#  'Longhai Li',
#  'Lorenzo Silengo',
#  'Luke A. Prendergast',
#  'Lungile Mdlazi',
#  'Lutz Brusch',
#  'M. I. Rabinovich',
#  'M. Sahani',
#  'Mai Suan Li',
#  'Manuel Middendorf',
#  'Marc Arnaudon',
#  'Marco Cuturi',
#  'Marie Cottrell',
#  'Mark A. Beaumont',
#  'Markus Bär',
#  'Marten Wegkamp',
#  'Martin G. Burke',
#  'Masami Miyakawa',
#  'Matthew C. Wiener',
#  'Matthew Carruth',
#  'Michael Hardy',
#  'Michael Hornquist',
#  'Michal Or-Guil',
#  'Michele Caselle',
#  'Mika Gustafsson',
#  'Miklós Csürös',
#  'Monica Lagazio',
#  'Mung-Chung Shung',
#  'Myoung Won Cho',
#  'N. Kopell',
#  'Nancy Kopell',
#  'Nestor Caticha',
#  'Nhu D Le',
#  'Nicolas Bray',
#  'Ning-Zhong Shi',
#  'Normand Mousseau',
#  'Olivier Alata',
#  'Olivier Cappé',
#  'P. Libros',
#  'P. P. Mitra',
#  'Paolo Provero',
#  'Patrice Gaubert',
#  'Patrick B. Warren',
#  'Patrick Letrémy',
#  'Paul J. Werbos',
#  'Paul Wiggins',
#  'Peter E. Latham',
#  'Peter Spreij',
#  'Philippe Derreumaux',
#  'Pieter Rein ten Wolde',
#  'R. A. Andersen',
#  'R. G. Khlebopros',
#  'R. Huerta',
#  'R. Lima',
#  'R. V. Krishnan',
#  'Randal Douc',
#  'Raydonal Ospina',
#  'Reka Albert',
#  'Rob Phillips',
#  'Robert Heckel',
#  'Robert Kohn',
#  'Roberto C. Alamino',
#  'Robin Koytcheff',
#  'Rodolphe Thiébaut',
#  'Rodrick Wallace',
#  'Rudiger Woscholski',
#  'Ruxandra I. Dima',
#  'S. Bumble',
#  'S. P. Gabuda',
#  'Sarjinder Singh',
#  'Satoshi Aoki',
#  'Seunghwan Kim',
#  'Shakir Mohamed',
#  'Shane T. Jensen',
#  'Sharad Saxena',
#  'Shihab A. Shamma',
#  'Shurong Zheng',
#  'Shuxia Song',
#  'Sibusiso Sibisi',
#  'Silvia L. P. Ferrari',
#  'Sophia N. Yaliraki',
#  'Stamatis Kolios',
#  'Stan Bumble',
#  'Stanislaw Cebrat',
#  'Stefano M. Iacus',
#  'Steven E. Brenner',
#  'Stéphanie Allassonnière',
#  'T. Vicsek',
#  'Teresa Head-Gordon',
#  'Thando Tettey',
#  'Thomas A. Down',
#  'Thomas S. Deisboeck',
#  'Tim Bedford',
#  'Tim J. P. Hubbard',
#  'Tinri Aegerter-Wilmsen',
#  'Ton Bisseling',
#  'Tshilidzi Marwala',
#  'Ursula Kummer',
#  'V. A. Slepkov',
#  'V. C. Barbosa',
#  'V. E. Fedorov',
#  'V. G. Sukhovolsky',
#  'Vitaliana Rondonotti',
#  'Voislav Golo',
#  'Wei-Mou Zheng',
#  'Wolfram Lorenz',
#  'Xiufang Wang',
#  'Xuming He',
#  'Y. V. Mironov',
#  'Yan Yuan Tseng',
#  'Yehuda Vardi',
#  'Yen-Jen Oyang',
#  'Yeong-Shyeong Tsai',
#  'Ying Lu',
#  'Ying-Lin Hsu',
#  'Yiping Dou',
#  'Yu-Yen Ou',
#  'Yuri Mansury',
#  'Zhai Yu',
#  'Zhanjun Lu',
#  'Zoltan Szabo',
#  'Zs. Kornyei'}
